# %%
import pandas as pd
import datetime as dt
import matplotlib.pyplot as plt
import sklearn
import seaborn as sns

import warnings
warnings.filterwarnings("ignore")

from yellowbrick.datasets import load_credit
from yellowbrick.features import PCA

# %%
df= pd.read_csv("lending_club_loan_two.csv")

# %%
df= df.dropna()
df
# Out:
#         loan_amnt        term  int_rate  installment grade sub_grade  \
# 0         10000.0   36 months     11.44       329.48     B        B4
# 1          8000.0   36 months     11.99       265.68     B        B5
# 2         15600.0   36 months     10.49       506.97     B        B3
# 3          7200.0   36 months      6.49       220.65     A        A2
# 4         24375.0   60 months     17.27       609.33     C        C5
# ...           ...         ...       ...          ...   ...       ...
# 396024     6000.0   36 months     13.11       202.49     B        B4
# 396025    10000.0   60 months     10.99       217.38     B        B4
# 396026    21000.0   36 months     12.29       700.42     C        C1
# 396027     5000.0   36 months      9.99       161.32     B        B1
# 396028    21000.0   60 months     15.31       503.02     C        C2
#
#                       emp_title emp_length home_ownership  annual_inc  ...  \
# 0                     Marketing  10+ years           RENT    117000.0  ...
# 1               Credit analyst     4 years       MORTGAGE     65000.0  ...
# 2                  Statistician   < 1 year           RENT     43057.0  ...
# 3               Client Advocate    6 years           RENT     54000.0  ...
# 4       Destiny Management Inc.    9 years       MORTGAGE     55000.0  ...
# ...                         ...        ...            ...         ...  ...
# 396024  Michael's Arts & Crafts    5 years           RENT     64000.0  ...
# 396025         licensed bankere    2 years           RENT     40000.0  ...
# 396026                    Agent    5 years       MORTGAGE    110000.0  ...
# 396027             City Carrier  10+ years           RENT     56500.0  ...
# 396028     Gracon Services, Inc  10+ years       MORTGAGE     64000.0  ...
#
#        open_acc pub_rec revol_bal revol_util total_acc  initial_list_status  \
# 0          16.0     0.0   36369.0       41.8      25.0                    w
# 1          17.0     0.0   20131.0       53.3      27.0                    f
# 2          13.0     0.0   11987.0       92.2      26.0                    f
# 3           6.0     0.0    5472.0       21.5      13.0                    f
# 4          13.0     0.0   24584.0       69.8      43.0                    f
# ...         ...     ...       ...        ...       ...                  ...
# 396024      7.0     0.0   11456.0       97.1       9.0                    w
# 396025      6.0     0.0    1990.0       34.3      23.0                    w
# 396026      6.0     0.0   43263.0       95.7       8.0                    f
# 396027     15.0     0.0   32704.0       66.9      23.0                    f
# 396028      9.0     0.0   15704.0       53.8      20.0                    f
#
#        application_type  mort_acc  pub_rec_bankruptcies  \
# 0            INDIVIDUAL       0.0                   0.0
# 1            INDIVIDUAL       3.0                   0.0
# 2            INDIVIDUAL       0.0                   0.0
# 3            INDIVIDUAL       0.0                   0.0
# 4            INDIVIDUAL       1.0                   0.0
# ...                 ...       ...                   ...
# 396024       INDIVIDUAL       0.0                   0.0
# 396025       INDIVIDUAL       0.0                   0.0
# 396026       INDIVIDUAL       1.0                   0.0
# 396027       INDIVIDUAL       0.0                   0.0
# 396028       INDIVIDUAL       5.0                   0.0
#
#                                                   address
# 0          0174 Michelle Gateway\r\nMendozaberg, OK 22690
# 1       1076 Carney Fort Apt. 347\r\nLoganmouth, SD 05113
# 2       87025 Mark Dale Apt. 269\r\nNew Sabrina, WV 05113
# 3                 823 Reid Ford\r\nDelacruzside, MA 00813
# 4                  679 Luna Roads\r\nGreggshire, VA 11650
# ...                                                   ...
# 396024  514 Cynthia Park Apt. 402\r\nWest Williamside,...
# 396025   12951 Williams Crossing\r\nJohnnyville, DC 30723
# 396026  0114 Fowler Field Suite 028\r\nRachelborough, ...
# 396027  953 Matthew Points Suite 414\r\nReedfort, NY 7...
# 396028  7843 Blake Freeway Apt. 229\r\nNew Michael, FL...
#
# [335868 rows x 27 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 335868 entries, 0 to 396028
# Data columns (total 27 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   loan_amnt             335868 non-null  float64
#  1   term                  335868 non-null  object
#  2   int_rate              335868 non-null  float64
#  3   installment           335868 non-null  float64
#  4   grade                 335868 non-null  object
#  5   sub_grade             335868 non-null  object
#  6   emp_title             335868 non-null  object
#  7   emp_length            335868 non-null  object
#  8   home_ownership        335868 non-null  object
#  9   annual_inc            335868 non-null  float64
#  10  verification_status   335868 non-null  object
#  11  issue_d               335868 non-null  object
#  12  loan_status           335868 non-null  object
#  13  purpose               335868 non-null  object
#  14  title                 335868 non-null  object
#  15  dti                   335868 non-null  float64
#  16  earliest_cr_line      335868 non-null  object
#  17  open_acc              335868 non-null  float64
#  18  pub_rec               335868 non-null  float64
#  19  revol_bal             335868 non-null  float64
#  20  revol_util            335868 non-null  float64
#  21  total_acc             335868 non-null  float64
#  22  initial_list_status   335868 non-null  object
#  23  application_type      335868 non-null  object
#  24  mort_acc              335868 non-null  float64
#  25  pub_rec_bankruptcies  335868 non-null  float64
#  26  address               335868 non-null  object
# dtypes: float64(12), object(15)
# memory usage: 71.7+ MB

# %%
df2 = df.copy()

# %%
df2.drop(columns = ['emp_title','home_ownership','title','earliest_cr_line','grade', 'address','purpose'],inplace=True)
df2
# Out:
#         loan_amnt        term  int_rate  installment sub_grade emp_length  \
# 0         10000.0   36 months     11.44       329.48        B4  10+ years
# 1          8000.0   36 months     11.99       265.68        B5    4 years
# 2         15600.0   36 months     10.49       506.97        B3   < 1 year
# 3          7200.0   36 months      6.49       220.65        A2    6 years
# 4         24375.0   60 months     17.27       609.33        C5    9 years
# ...           ...         ...       ...          ...       ...        ...
# 396024     6000.0   36 months     13.11       202.49        B4    5 years
# 396025    10000.0   60 months     10.99       217.38        B4    2 years
# 396026    21000.0   36 months     12.29       700.42        C1    5 years
# 396027     5000.0   36 months      9.99       161.32        B1  10+ years
# 396028    21000.0   60 months     15.31       503.02        C2  10+ years
#
#         annual_inc verification_status   issue_d  loan_status    dti  \
# 0         117000.0        Not Verified  Jan-2015   Fully Paid  26.24
# 1          65000.0        Not Verified  Jan-2015   Fully Paid  22.05
# 2          43057.0     Source Verified  Jan-2015   Fully Paid  12.79
# 3          54000.0        Not Verified  Nov-2014   Fully Paid   2.60
# 4          55000.0            Verified  Apr-2013  Charged Off  33.95
# ...            ...                 ...       ...          ...    ...
# 396024     64000.0        Not Verified  Mar-2013   Fully Paid  10.81
# 396025     40000.0     Source Verified  Oct-2015   Fully Paid  15.63
# 396026    110000.0     Source Verified  Feb-2015   Fully Paid  21.45
# 396027     56500.0            Verified  Oct-2013   Fully Paid  17.56
# 396028     64000.0            Verified  Aug-2012   Fully Paid  15.88
#
#         open_acc  pub_rec  revol_bal  revol_util  total_acc  \
# 0           16.0      0.0    36369.0        41.8       25.0
# 1           17.0      0.0    20131.0        53.3       27.0
# 2           13.0      0.0    11987.0        92.2       26.0
# 3            6.0      0.0     5472.0        21.5       13.0
# 4           13.0      0.0    24584.0        69.8       43.0
# ...          ...      ...        ...         ...        ...
# 396024       7.0      0.0    11456.0        97.1        9.0
# 396025       6.0      0.0     1990.0        34.3       23.0
# 396026       6.0      0.0    43263.0        95.7        8.0
# 396027      15.0      0.0    32704.0        66.9       23.0
# 396028       9.0      0.0    15704.0        53.8       20.0
#
#        initial_list_status application_type  mort_acc  pub_rec_bankruptcies
# 0                        w       INDIVIDUAL       0.0                   0.0
# 1                        f       INDIVIDUAL       3.0                   0.0
# 2                        f       INDIVIDUAL       0.0                   0.0
# 3                        f       INDIVIDUAL       0.0                   0.0
# 4                        f       INDIVIDUAL       1.0                   0.0
# ...                    ...              ...       ...                   ...
# 396024                   w       INDIVIDUAL       0.0                   0.0
# 396025                   w       INDIVIDUAL       0.0                   0.0
# 396026                   f       INDIVIDUAL       1.0                   0.0
# 396027                   f       INDIVIDUAL       0.0                   0.0
# 396028                   f       INDIVIDUAL       5.0                   0.0
#
# [335868 rows x 20 columns]

# %%
df2['issue_d']= pd.DatetimeIndex(df['issue_d'])

# %%
df2.term.replace({' 36 months':36 , ' 60 months':60}, inplace=True)
df2
# Out:
#         loan_amnt  term  int_rate  installment sub_grade emp_length  \
# 0         10000.0    36     11.44       329.48        B4  10+ years
# 1          8000.0    36     11.99       265.68        B5    4 years
# 2         15600.0    36     10.49       506.97        B3   < 1 year
# 3          7200.0    36      6.49       220.65        A2    6 years
# 4         24375.0    60     17.27       609.33        C5    9 years
# ...           ...   ...       ...          ...       ...        ...
# 396024     6000.0    36     13.11       202.49        B4    5 years
# 396025    10000.0    60     10.99       217.38        B4    2 years
# 396026    21000.0    36     12.29       700.42        C1    5 years
# 396027     5000.0    36      9.99       161.32        B1  10+ years
# 396028    21000.0    60     15.31       503.02        C2  10+ years
#
#         annual_inc verification_status    issue_d  loan_status    dti  \
# 0         117000.0        Not Verified 2015-01-01   Fully Paid  26.24
# 1          65000.0        Not Verified 2015-01-01   Fully Paid  22.05
# 2          43057.0     Source Verified 2015-01-01   Fully Paid  12.79
# 3          54000.0        Not Verified 2014-11-01   Fully Paid   2.60
# 4          55000.0            Verified 2013-04-01  Charged Off  33.95
# ...            ...                 ...        ...          ...    ...
# 396024     64000.0        Not Verified 2013-03-01   Fully Paid  10.81
# 396025     40000.0     Source Verified 2015-10-01   Fully Paid  15.63
# 396026    110000.0     Source Verified 2015-02-01   Fully Paid  21.45
# 396027     56500.0            Verified 2013-10-01   Fully Paid  17.56
# 396028     64000.0            Verified 2012-08-01   Fully Paid  15.88
#
#         open_acc  pub_rec  revol_bal  revol_util  total_acc  \
# 0           16.0      0.0    36369.0        41.8       25.0
# 1           17.0      0.0    20131.0        53.3       27.0
# 2           13.0      0.0    11987.0        92.2       26.0
# 3            6.0      0.0     5472.0        21.5       13.0
# 4           13.0      0.0    24584.0        69.8       43.0
# ...          ...      ...        ...         ...        ...
# 396024       7.0      0.0    11456.0        97.1        9.0
# 396025       6.0      0.0     1990.0        34.3       23.0
# 396026       6.0      0.0    43263.0        95.7        8.0
# 396027      15.0      0.0    32704.0        66.9       23.0
# 396028       9.0      0.0    15704.0        53.8       20.0
#
#        initial_list_status application_type  mort_acc  pub_rec_bankruptcies
# 0                        w       INDIVIDUAL       0.0                   0.0
# 1                        f       INDIVIDUAL       3.0                   0.0
# 2                        f       INDIVIDUAL       0.0                   0.0
# 3                        f       INDIVIDUAL       0.0                   0.0
# 4                        f       INDIVIDUAL       1.0                   0.0
# ...                    ...              ...       ...                   ...
# 396024                   w       INDIVIDUAL       0.0                   0.0
# 396025                   w       INDIVIDUAL       0.0                   0.0
# 396026                   f       INDIVIDUAL       1.0                   0.0
# 396027                   f       INDIVIDUAL       0.0                   0.0
# 396028                   f       INDIVIDUAL       5.0                   0.0
#
# [335868 rows x 20 columns]

# %%
df2.sub_grade.sort_values().unique()
# Out:
# array(['A1', 'A2', 'A3', 'A4', 'A5', 'B1', 'B2', 'B3', 'B4', 'B5', 'C1',
#        'C2', 'C3', 'C4', 'C5', 'D1', 'D2', 'D3', 'D4', 'D5', 'E1', 'E2',
#        'E3', 'E4', 'E5', 'F1', 'F2', 'F3', 'F4', 'F5', 'G1', 'G2', 'G3',
#        'G4', 'G5'], dtype=object)

# %%
df2.verification_status.unique()
# Out:
# array(['Not Verified', 'Source Verified', 'Verified'], dtype=object)

# %%
df2.verification_status.replace ({'Not Verified':-1, 'Source Verified':0, 'Verified':1},inplace= True)
df2
# Out:
#         loan_amnt  term  int_rate  installment sub_grade emp_length  \
# 0         10000.0    36     11.44       329.48        B4  10+ years
# 1          8000.0    36     11.99       265.68        B5    4 years
# 2         15600.0    36     10.49       506.97        B3   < 1 year
# 3          7200.0    36      6.49       220.65        A2    6 years
# 4         24375.0    60     17.27       609.33        C5    9 years
# ...           ...   ...       ...          ...       ...        ...
# 396024     6000.0    36     13.11       202.49        B4    5 years
# 396025    10000.0    60     10.99       217.38        B4    2 years
# 396026    21000.0    36     12.29       700.42        C1    5 years
# 396027     5000.0    36      9.99       161.32        B1  10+ years
# 396028    21000.0    60     15.31       503.02        C2  10+ years
#
#         annual_inc  verification_status    issue_d  loan_status    dti  \
# 0         117000.0                   -1 2015-01-01   Fully Paid  26.24
# 1          65000.0                   -1 2015-01-01   Fully Paid  22.05
# 2          43057.0                    0 2015-01-01   Fully Paid  12.79
# 3          54000.0                   -1 2014-11-01   Fully Paid   2.60
# 4          55000.0                    1 2013-04-01  Charged Off  33.95
# ...            ...                  ...        ...          ...    ...
# 396024     64000.0                   -1 2013-03-01   Fully Paid  10.81
# 396025     40000.0                    0 2015-10-01   Fully Paid  15.63
# 396026    110000.0                    0 2015-02-01   Fully Paid  21.45
# 396027     56500.0                    1 2013-10-01   Fully Paid  17.56
# 396028     64000.0                    1 2012-08-01   Fully Paid  15.88
#
#         open_acc  pub_rec  revol_bal  revol_util  total_acc  \
# 0           16.0      0.0    36369.0        41.8       25.0
# 1           17.0      0.0    20131.0        53.3       27.0
# 2           13.0      0.0    11987.0        92.2       26.0
# 3            6.0      0.0     5472.0        21.5       13.0
# 4           13.0      0.0    24584.0        69.8       43.0
# ...          ...      ...        ...         ...        ...
# 396024       7.0      0.0    11456.0        97.1        9.0
# 396025       6.0      0.0     1990.0        34.3       23.0
# 396026       6.0      0.0    43263.0        95.7        8.0
# 396027      15.0      0.0    32704.0        66.9       23.0
# 396028       9.0      0.0    15704.0        53.8       20.0
#
#        initial_list_status application_type  mort_acc  pub_rec_bankruptcies
# 0                        w       INDIVIDUAL       0.0                   0.0
# 1                        f       INDIVIDUAL       3.0                   0.0
# 2                        f       INDIVIDUAL       0.0                   0.0
# 3                        f       INDIVIDUAL       0.0                   0.0
# 4                        f       INDIVIDUAL       1.0                   0.0
# ...                    ...              ...       ...                   ...
# 396024                   w       INDIVIDUAL       0.0                   0.0
# 396025                   w       INDIVIDUAL       0.0                   0.0
# 396026                   f       INDIVIDUAL       1.0                   0.0
# 396027                   f       INDIVIDUAL       0.0                   0.0
# 396028                   f       INDIVIDUAL       5.0                   0.0
#
# [335868 rows x 20 columns]

# %%
df2.sub_grade.replace({'A1':71, 'A2':72, 'A3':73, 'A4':74, 'A5':75, 'B1':61, 'B2':62, 'B3':63, 'B4':64, 'B5':65, 'C1':51,
       'C2':52, 'C3':53, 'C4':54, 'C5':55, 'D1':41, 'D2':42, 'D3':43, 'D4':44, 'D5':45, 'E1':31, 'E2':32,
       'E3':33, 'E4':34, 'E5':35, 'F1':21, 'F2':22, 'F3':23, 'F4':24, 'F5':25, 'G1':11, 'G2':12, 'G3':13,
       'G4':14, 'G5':15}, inplace= True)
df2
# Out:
#         loan_amnt  term  int_rate  installment  sub_grade emp_length  \
# 0         10000.0    36     11.44       329.48         64  10+ years
# 1          8000.0    36     11.99       265.68         65    4 years
# 2         15600.0    36     10.49       506.97         63   < 1 year
# 3          7200.0    36      6.49       220.65         72    6 years
# 4         24375.0    60     17.27       609.33         55    9 years
# ...           ...   ...       ...          ...        ...        ...
# 396024     6000.0    36     13.11       202.49         64    5 years
# 396025    10000.0    60     10.99       217.38         64    2 years
# 396026    21000.0    36     12.29       700.42         51    5 years
# 396027     5000.0    36      9.99       161.32         61  10+ years
# 396028    21000.0    60     15.31       503.02         52  10+ years
#
#         annual_inc  verification_status    issue_d  loan_status    dti  \
# 0         117000.0                   -1 2015-01-01   Fully Paid  26.24
# 1          65000.0                   -1 2015-01-01   Fully Paid  22.05
# 2          43057.0                    0 2015-01-01   Fully Paid  12.79
# 3          54000.0                   -1 2014-11-01   Fully Paid   2.60
# 4          55000.0                    1 2013-04-01  Charged Off  33.95
# ...            ...                  ...        ...          ...    ...
# 396024     64000.0                   -1 2013-03-01   Fully Paid  10.81
# 396025     40000.0                    0 2015-10-01   Fully Paid  15.63
# 396026    110000.0                    0 2015-02-01   Fully Paid  21.45
# 396027     56500.0                    1 2013-10-01   Fully Paid  17.56
# 396028     64000.0                    1 2012-08-01   Fully Paid  15.88
#
#         open_acc  pub_rec  revol_bal  revol_util  total_acc  \
# 0           16.0      0.0    36369.0        41.8       25.0
# 1           17.0      0.0    20131.0        53.3       27.0
# 2           13.0      0.0    11987.0        92.2       26.0
# 3            6.0      0.0     5472.0        21.5       13.0
# 4           13.0      0.0    24584.0        69.8       43.0
# ...          ...      ...        ...         ...        ...
# 396024       7.0      0.0    11456.0        97.1        9.0
# 396025       6.0      0.0     1990.0        34.3       23.0
# 396026       6.0      0.0    43263.0        95.7        8.0
# 396027      15.0      0.0    32704.0        66.9       23.0
# 396028       9.0      0.0    15704.0        53.8       20.0
#
#        initial_list_status application_type  mort_acc  pub_rec_bankruptcies
# 0                        w       INDIVIDUAL       0.0                   0.0
# 1                        f       INDIVIDUAL       3.0                   0.0
# 2                        f       INDIVIDUAL       0.0                   0.0
# 3                        f       INDIVIDUAL       0.0                   0.0
# 4                        f       INDIVIDUAL       1.0                   0.0
# ...                    ...              ...       ...                   ...
# 396024                   w       INDIVIDUAL       0.0                   0.0
# 396025                   w       INDIVIDUAL       0.0                   0.0
# 396026                   f       INDIVIDUAL       1.0                   0.0
# 396027                   f       INDIVIDUAL       0.0                   0.0
# 396028                   f       INDIVIDUAL       5.0                   0.0
#
# [335868 rows x 20 columns]

# %%
df2.application_type.unique()
# Out:
# array(['INDIVIDUAL', 'JOINT', 'DIRECT_PAY'], dtype=object)

# %%
df2.application_type.replace({'INDIVIDUAL':1, 'JOINT':2, 'DIRECT_PAY':3}, inplace=True)
df2
# Out:
#         loan_amnt  term  int_rate  installment  sub_grade emp_length  \
# 0         10000.0    36     11.44       329.48         64  10+ years
# 1          8000.0    36     11.99       265.68         65    4 years
# 2         15600.0    36     10.49       506.97         63   < 1 year
# 3          7200.0    36      6.49       220.65         72    6 years
# 4         24375.0    60     17.27       609.33         55    9 years
# ...           ...   ...       ...          ...        ...        ...
# 396024     6000.0    36     13.11       202.49         64    5 years
# 396025    10000.0    60     10.99       217.38         64    2 years
# 396026    21000.0    36     12.29       700.42         51    5 years
# 396027     5000.0    36      9.99       161.32         61  10+ years
# 396028    21000.0    60     15.31       503.02         52  10+ years
#
#         annual_inc  verification_status    issue_d  loan_status    dti  \
# 0         117000.0                   -1 2015-01-01   Fully Paid  26.24
# 1          65000.0                   -1 2015-01-01   Fully Paid  22.05
# 2          43057.0                    0 2015-01-01   Fully Paid  12.79
# 3          54000.0                   -1 2014-11-01   Fully Paid   2.60
# 4          55000.0                    1 2013-04-01  Charged Off  33.95
# ...            ...                  ...        ...          ...    ...
# 396024     64000.0                   -1 2013-03-01   Fully Paid  10.81
# 396025     40000.0                    0 2015-10-01   Fully Paid  15.63
# 396026    110000.0                    0 2015-02-01   Fully Paid  21.45
# 396027     56500.0                    1 2013-10-01   Fully Paid  17.56
# 396028     64000.0                    1 2012-08-01   Fully Paid  15.88
#
#         open_acc  pub_rec  revol_bal  revol_util  total_acc  \
# 0           16.0      0.0    36369.0        41.8       25.0
# 1           17.0      0.0    20131.0        53.3       27.0
# 2           13.0      0.0    11987.0        92.2       26.0
# 3            6.0      0.0     5472.0        21.5       13.0
# 4           13.0      0.0    24584.0        69.8       43.0
# ...          ...      ...        ...         ...        ...
# 396024       7.0      0.0    11456.0        97.1        9.0
# 396025       6.0      0.0     1990.0        34.3       23.0
# 396026       6.0      0.0    43263.0        95.7        8.0
# 396027      15.0      0.0    32704.0        66.9       23.0
# 396028       9.0      0.0    15704.0        53.8       20.0
#
#        initial_list_status  application_type  mort_acc  pub_rec_bankruptcies
# 0                        w                 1       0.0                   0.0
# 1                        f                 1       3.0                   0.0
# 2                        f                 1       0.0                   0.0
# 3                        f                 1       0.0                   0.0
# 4                        f                 1       1.0                   0.0
# ...                    ...               ...       ...                   ...
# 396024                   w                 1       0.0                   0.0
# 396025                   w                 1       0.0                   0.0
# 396026                   f                 1       1.0                   0.0
# 396027                   f                 1       0.0                   0.0
# 396028                   f                 1       5.0                   0.0
#
# [335868 rows x 20 columns]

# %%
df2.emp_length.unique()
# Out:
# array(['10+ years', '4 years', '< 1 year', '6 years', '9 years',
#        '2 years', '3 years', '8 years', '7 years', '5 years', '1 year'],
#       dtype=object)

# %%
df2.emp_length.replace({'< 1 year':0,'1 year':1,'2 years':2, '3 years':3, '4 years':4, '5 years':5, '6 years':6, '7 years':7,'8 years':8, '9 years':9, '10+ years': 10}, inplace=True)

# %%
df2.initial_list_status.unique()
# Out:
# array(['w', 'f'], dtype=object)

# %%
df2.initial_list_status.replace({'w':0,'f':1},inplace=True)
df2
# Out:
#         loan_amnt  term  int_rate  installment  sub_grade  emp_length  \
# 0         10000.0    36     11.44       329.48         64          10
# 1          8000.0    36     11.99       265.68         65           4
# 2         15600.0    36     10.49       506.97         63           0
# 3          7200.0    36      6.49       220.65         72           6
# 4         24375.0    60     17.27       609.33         55           9
# ...           ...   ...       ...          ...        ...         ...
# 396024     6000.0    36     13.11       202.49         64           5
# 396025    10000.0    60     10.99       217.38         64           2
# 396026    21000.0    36     12.29       700.42         51           5
# 396027     5000.0    36      9.99       161.32         61          10
# 396028    21000.0    60     15.31       503.02         52          10
#
#         annual_inc  verification_status    issue_d  loan_status    dti  \
# 0         117000.0                   -1 2015-01-01   Fully Paid  26.24
# 1          65000.0                   -1 2015-01-01   Fully Paid  22.05
# 2          43057.0                    0 2015-01-01   Fully Paid  12.79
# 3          54000.0                   -1 2014-11-01   Fully Paid   2.60
# 4          55000.0                    1 2013-04-01  Charged Off  33.95
# ...            ...                  ...        ...          ...    ...
# 396024     64000.0                   -1 2013-03-01   Fully Paid  10.81
# 396025     40000.0                    0 2015-10-01   Fully Paid  15.63
# 396026    110000.0                    0 2015-02-01   Fully Paid  21.45
# 396027     56500.0                    1 2013-10-01   Fully Paid  17.56
# 396028     64000.0                    1 2012-08-01   Fully Paid  15.88
#
#         open_acc  pub_rec  revol_bal  revol_util  total_acc  \
# 0           16.0      0.0    36369.0        41.8       25.0
# 1           17.0      0.0    20131.0        53.3       27.0
# 2           13.0      0.0    11987.0        92.2       26.0
# 3            6.0      0.0     5472.0        21.5       13.0
# 4           13.0      0.0    24584.0        69.8       43.0
# ...          ...      ...        ...         ...        ...
# 396024       7.0      0.0    11456.0        97.1        9.0
# 396025       6.0      0.0     1990.0        34.3       23.0
# 396026       6.0      0.0    43263.0        95.7        8.0
# 396027      15.0      0.0    32704.0        66.9       23.0
# 396028       9.0      0.0    15704.0        53.8       20.0
#
#         initial_list_status  application_type  mort_acc  pub_rec_bankruptcies
# 0                         0                 1       0.0                   0.0
# 1                         1                 1       3.0                   0.0
# 2                         1                 1       0.0                   0.0
# 3                         1                 1       0.0                   0.0
# 4                         1                 1       1.0                   0.0
# ...                     ...               ...       ...                   ...
# 396024                    0                 1       0.0                   0.0
# 396025                    0                 1       0.0                   0.0
# 396026                    1                 1       1.0                   0.0
# 396027                    1                 1       0.0                   0.0
# 396028                    1                 1       5.0                   0.0
#
# [335868 rows x 20 columns]

# %%
y= df2.loan_status == 'Charged Off'

# %%
df2.drop(columns = ['loan_status'],inplace=True)

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 335868 entries, 0 to 396028
# Data columns (total 19 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   loan_amnt             335868 non-null  float64
#  1   term                  335868 non-null  int64
#  2   int_rate              335868 non-null  float64
#  3   installment           335868 non-null  float64
#  4   sub_grade             335868 non-null  int64
#  5   emp_length            335868 non-null  int64
#  6   annual_inc            335868 non-null  float64
#  7   verification_status   335868 non-null  int64
#  8   issue_d               335868 non-null  datetime64[ns]
#  9   dti                   335868 non-null  float64
#  10  open_acc              335868 non-null  float64
#  11  pub_rec               335868 non-null  float64
#  12  revol_bal             335868 non-null  float64
#  13  revol_util            335868 non-null  float64
#  14  total_acc             335868 non-null  float64
#  15  initial_list_status   335868 non-null  int64
#  16  application_type      335868 non-null  int64
#  17  mort_acc              335868 non-null  float64
#  18  pub_rec_bankruptcies  335868 non-null  float64
# dtypes: datetime64[ns](1), float64(12), int64(6)
# memory usage: 51.2 MB

# %%
visualize_cols=['loan_amnt','term','int_rate','installment','sub_grade','emp_length','verification_status','initial_list_status','application_type',
                'annual_inc','dti','open_acc',
                'pub_rec','revol_bal','revol_util', 
                'total_acc','mort_acc','pub_rec_bankruptcies']
plt.figure(figsize=(30,30))

for i in range(len(visualize_cols)):
    plt.subplot(5,5,i+1)
    sns.distplot(df2[visualize_cols[i]])
plt.show()

# %%
X= df2
classes= ['Fully Paid', 'Charged Off']

# %%
X[X.columns]= X[X.columns].apply(pd.to_numeric, errors='coerce')
X.dropna(axis=1, inplace=True)
visualizer= PCA(scale= True, classes= classes)
visualizer.fit_transform(X,y.values +1-1)
visualizer.show()
# Out:
# <AxesSubplot:title={'center':'Principal Component Plot'}, xlabel='$PC_1$', ylabel='$PC_2$'>
